# %% [markdown]
# Results
# ---
#
# *Script von David Steyrl*
#
# 25.04.2022
# * Dataset: "complete" (50 features):
#     * 23 items of FFMQ
#     * 20 items of UPPS-P
#     * 5 items of DMQ-coping
#     * 1 item for weekly working hours
#     * 1 item for sex
#
# * Tested regressors:
#     * LGBMRegressor (lightgbm)
#
# * Cross validation:
#     * 50 shuffle splits outer loop
#     * 50 shuffle splits inner loop with bayesian hyperparameter optimization

# %% [markdown]
# ## model scores
#
# ```ExtraTreesRegressor  => mean R²: 0.294```
#
# Zum Vergleich (08.04.): ```ExtraTreesRegressor  => mean R²: 0.307 (train: 0.820)```

# %%
import pickle
import pandas as pd
  
# Open the file in binary mode
with open('results_audit.pickle', 'rb') as fo:
      
    # Call load method to deserialze
    results = pickle.load(fo)
    
#print("results keys:",results.keys(),"\n")

df_scores = pd.DataFrame(results["scores"]).apply(lambda row: pd.Series({"mae":row[0][0],"mse":row[1][0],"curr_loop_R2":row[2][0]}),axis=1)
print(df_scores.round(3))
print("\nmeans:")
print(df_scores.mean())
# Out:
#       mae     mse  curr_loop_R2
# 0   2.713  13.151         0.404
# 1   2.930  18.341         0.323
# 2   2.753  13.882         0.346
# 3   2.586  13.002         0.380
# 4   2.782  14.321         0.355
# 5   2.241   9.483         0.249
# 6   2.845  15.425         0.291
# 7   2.610  13.271         0.348
# 8   2.512  11.295         0.204
# 9   2.924  17.115         0.241
# 10  2.821  15.139         0.294
# 11  2.919  18.840         0.277
# 12  2.628  12.958         0.343
# 13  2.670  11.680         0.255
# 14  2.921  15.761         0.251
# 15  2.528  11.116         0.269
# 16  2.997  16.779         0.345
# 17  2.382  12.976         0.376
# 18  2.628  14.626         0.285
# 19  2.627  13.400         0.287
# 20  2.718  11.667         0.204
# 21  2.353   8.279         0.285
# 22  2.681  12.996         0.308
# 23  2.741  16.027         0.348
# 24  2.719  12.917         0.313
# 25  2.912  16.911         0.281
# 26  2.694  11.538         0.171
# 27  2.761  13.713         0.283
# ...

# %% [markdown]
# ## plots

# %% [markdown]
# ```ET_fit_reg_violin_audit```

# %% [markdown]
# <img src='plots_audit/ET_fit_reg_violin_audit.png' alt="plot" width="600">

# %% [markdown]
# ```ET_fit_scatter_audit```

# %% [markdown]
# <img src='plots_audit/ET_fit_scatter_audit.png' alt="plot" width="600">

# %% [markdown]
# ```ET_m_imp_audit```

# %% [markdown]
# <img src='plots_audit/ET_m_imp_audit.png' alt="plot" width="600">

# %% [markdown]
# ```ET_p_imp_audit```

# %% [markdown]
# <img src='plots_audit/ET_p_imp_audit.png' alt="plot" width="600">

# %% [markdown]
# ```ET_s_imp_audit```

# %% [markdown]
# <img src='plots_audit/ET_s_imp_audit.png' alt="plot" width="600">

# %% [markdown]
# ```ET_shape_values_audit```

# %% [markdown]
# <img src='plots_audit/ET_shape_values_audit.png' alt="plot" width="600">

# %% [markdown]
# ## script output

# %% [markdown]
# ```
# Dataset: data/mindfulness.csv
# n rep outer cv: 50 | n rep inner cv: 50 | ET
#
#
# 0.0 |
# Best R2: 0.293 | OrderedDict([('max_features', 0.4510639312959351), ('min_samples_leaf', 1), ('min_samples_split', 20), ('n_estimators', 500)])
# Current CV loop R2: [0.4042]
# Running mean R2: 0.4042
# Running shuffle mean R2: 0.0393
# Elapsed time: 643.7
#
#
# 0.1 |
# Best R2: 0.316 | OrderedDict([('max_features', 0.4132094417891655), ('min_samples_leaf', 4), ('min_samples_split', 6), ('n_estimators', 500)])
# Current CV loop R2: [0.3233]
# Running mean R2: 0.3638
# Running shuffle mean R2: 0.0137
# Elapsed time: 650.0
#
#
# 0.2 |
# Best R2: 0.3202 | OrderedDict([('max_features', 0.41067914750237144), ('min_samples_leaf', 1), ('min_samples_split', 8), ('n_estimators', 500)])
# Current CV loop R2: [0.3465]
# Running mean R2: 0.358
# Running shuffle mean R2: -0.0186
# Elapsed time: 667.3
#
#
# 0.3 |
# Best R2: 0.3443 | OrderedDict([('max_features', 0.2373000244281572), ('min_samples_leaf', 1), ('min_samples_split', 6), ('n_estimators', 500)])
# Current CV loop R2: [0.3801]
# Running mean R2: 0.3635
# Running shuffle mean R2: -0.0262
# Elapsed time: 659.7
#
#
# 0.4 |
# Best R2: 0.2995 | OrderedDict([('max_features', 0.407620206165409), ('min_samples_leaf', 1), ('min_samples_split', 30), ('n_estimators', 115)])
# Current CV loop R2: [0.3554]
# Running mean R2: 0.3619
# Running shuffle mean R2: -0.0283
# Elapsed time: 443.3
#
#
# 0.5 |
# Best R2: 0.3357 | OrderedDict([('max_features', 0.28329723618594926), ('min_samples_leaf', 1), ('min_samples_split', 4), ('n_estimators', 150)])
# Current CV loop R2: [0.249]
# Running mean R2: 0.3431
# Running shuffle mean R2: -0.0372
# Elapsed time: 472.8
#
#
# 0.6 |
# Best R2: 0.3371 | OrderedDict([('max_features', 0.5837898161035143), ('min_samples_leaf', 1), ('min_samples_split', 14), ('n_estimators', 500)])
# Current CV loop R2: [0.2907]
# Running mean R2: 0.3356
# Running shuffle mean R2: -0.0346
# Elapsed time: 726.3
#
#
# 0.7 |
# Best R2: 0.3141 | OrderedDict([('max_features', 0.5478799359405855), ('min_samples_leaf', 1), ('min_samples_split', 33), ('n_estimators', 135)])
# Current CV loop R2: [0.3484]
# Running mean R2: 0.3372
# Running shuffle mean R2: -0.0242
# Elapsed time: 458.2
#
#
# 0.8 |
# Best R2: 0.3235 | OrderedDict([('max_features', 0.459800359272065), ('min_samples_leaf', 1), ('min_samples_split', 7), ('n_estimators', 71)])
# Current CV loop R2: [0.204]
# Running mean R2: 0.3224
# Running shuffle mean R2: -0.0295
# Elapsed time: 401.4
#
#
# 0.9 |
# Best R2: 0.3108 | OrderedDict([('max_features', 0.5042755461454536), ('min_samples_leaf', 1), ('min_samples_split', 83), ('n_estimators', 191)])
# Current CV loop R2: [0.2408]
# Running mean R2: 0.3143
# Running shuffle mean R2: -0.0308
# Elapsed time: 485.3
#
#
# 0.10 |
# Best R2: 0.3301 | OrderedDict([('max_features', 0.4332919086849592), ('min_samples_leaf', 4), ('min_samples_split', 10), ('n_estimators', 500)])
# Current CV loop R2: [0.2942]
# Running mean R2: 0.3124
# Running shuffle mean R2: -0.0334
# Elapsed time: 636.8
#
#
# 0.11 |
# Best R2: 0.3517 | OrderedDict([('max_features', 0.5909960877151538), ('min_samples_leaf', 2), ('min_samples_split', 12), ('n_estimators', 500)])
# Current CV loop R2: [0.2774]
# Running mean R2: 0.3095
# Running shuffle mean R2: -0.0292
# Elapsed time: 669.7
#
#
# 0.12 |
# Best R2: 0.3262 | OrderedDict([('max_features', 0.3272229932021928), ('min_samples_leaf', 1), ('min_samples_split', 12), ('n_estimators', 500)])
# Current CV loop R2: [0.3425]
# Running mean R2: 0.3121
# Running shuffle mean R2: -0.0267
# Elapsed time: 618.3
#
#
# 0.13 |
# Best R2: 0.3394 | OrderedDict([('max_features', 0.4119061499466267), ('min_samples_leaf', 1), ('min_samples_split', 9), ('n_estimators', 117)])
# Current CV loop R2: [0.2547]
# Running mean R2: 0.308
# Running shuffle mean R2: -0.0138
# Elapsed time: 468.4
#
#
# 0.14 |
# Best R2: 0.3481 | OrderedDict([('max_features', 0.4822045958667663), ('min_samples_leaf', 3), ('min_samples_split', 2), ('n_estimators', 182)])
# Current CV loop R2: [0.2509]
# Running mean R2: 0.3042
# Running shuffle mean R2: -0.0172
# Elapsed time: 498.4
#
#
# 0.15 |
# Best R2: 0.3331 | OrderedDict([('max_features', 0.7059296083032355), ('min_samples_leaf', 8), ('min_samples_split', 2), ('n_estimators', 171)])
# Current CV loop R2: [0.2691]
# Running mean R2: 0.302
# Running shuffle mean R2: -0.0171
# Elapsed time: 419.0
#
#
# 0.16 |
# Best R2: 0.3524 | OrderedDict([('max_features', 0.4834164204920926), ('min_samples_leaf', 1), ('min_samples_split', 4), ('n_estimators', 500)])
# Current CV loop R2: [0.3454]
# Running mean R2: 0.3045
# Running shuffle mean R2: -0.0138
# Elapsed time: 701.5
#
#
# 0.17 |
# Best R2: 0.328 | OrderedDict([('max_features', 0.6237793056295864), ('min_samples_leaf', 1), ('min_samples_split', 5), ('n_estimators', 500)])
# Current CV loop R2: [0.3762]
# Running mean R2: 0.3085
# Running shuffle mean R2: -0.0073
# Elapsed time: 737.7
#
#
# 0.18 |
# Best R2: 0.3656 | OrderedDict([('max_features', 0.364609731139403), ('min_samples_leaf', 1), ('min_samples_split', 13), ('n_estimators', 500)])
# Current CV loop R2: [0.2846]
# Running mean R2: 0.3072
# Running shuffle mean R2: -0.0079
# Elapsed time: 626.3
#
#
# 0.19 |
# Best R2: 0.329 | OrderedDict([('max_features', 0.5985364300979564), ('min_samples_leaf', 10), ('min_samples_split', 4), ('n_estimators', 142)])
# Current CV loop R2: [0.2865]
# Running mean R2: 0.3062
# Running shuffle mean R2: -0.0056
# Elapsed time: 454.8
#
#
# 0.20 |
# Best R2: 0.3317 | OrderedDict([('max_features', 0.2823034670751725), ('min_samples_leaf', 1), ('min_samples_split', 6), ('n_estimators', 102)])
# Current CV loop R2: [0.2042]
# Running mean R2: 0.3014
# Running shuffle mean R2: -0.0012
# Elapsed time: 454.9
#
#
# 0.21 |
# Best R2: 0.3325 | OrderedDict([('max_features', 0.44814463817436373), ('min_samples_leaf', 1), ('min_samples_split', 17), ('n_estimators', 164)])
# Current CV loop R2: [0.2846]
# Running mean R2: 0.3006
# Running shuffle mean R2: -0.0061
# Elapsed time: 506.5
#
#
# 0.22 |
# Best R2: 0.3245 | OrderedDict([('max_features', 0.8367819769977619), ('min_samples_leaf', 7), ('min_samples_split', 12), ('n_estimators', 269)])
# Current CV loop R2: [0.3077]
# Running mean R2: 0.3009
# Running shuffle mean R2: -0.0105
# Elapsed time: 557.8
#
#
# 0.23 |
# Best R2: 0.3271 | OrderedDict([('max_features', 0.3868649042338909), ('min_samples_leaf', 1), ('min_samples_split', 2), ('n_estimators', 500)])
# Current CV loop R2: [0.3478]
# Running mean R2: 0.3029
# Running shuffle mean R2: -0.0159
# Elapsed time: 685.9
#
#
# 0.24 |
# Best R2: 0.3399 | OrderedDict([('max_features', 0.24537982513101386), ('min_samples_leaf', 1), ('min_samples_split', 9), ('n_estimators', 53)])
# Current CV loop R2: [0.3134]
# Running mean R2: 0.3033
# Running shuffle mean R2: -0.0166
# Elapsed time: 445.3
#
#
# 0.25 |
# Best R2: 0.3444 | OrderedDict([('max_features', 0.4631664537365865), ('min_samples_leaf', 1), ('min_samples_split', 12), ('n_estimators', 500)])
# Current CV loop R2: [0.2807]
# Running mean R2: 0.3024
# Running shuffle mean R2: -0.0189
# Elapsed time: 645.1
#
#
# 0.26 |
# Best R2: 0.361 | OrderedDict([('max_features', 0.6012521430131581), ('min_samples_leaf', 7), ('min_samples_split', 2), ('n_estimators', 500)])
# Current CV loop R2: [0.1715]
# Running mean R2: 0.2976
# Running shuffle mean R2: -0.0218
# Elapsed time: 638.1
#
#
# 0.27 |
# Best R2: 0.3343 | OrderedDict([('max_features', 0.4543757115197036), ('min_samples_leaf', 1), ('min_samples_split', 8), ('n_estimators', 231)])
# Current CV loop R2: [0.2825]
# Running mean R2: 0.297
# Running shuffle mean R2: -0.0259
# Elapsed time: 494.2
#
#
# 0.28 |
# Best R2: 0.3508 | OrderedDict([('max_features', 0.35614640141282145), ('min_samples_leaf', 1), ('min_samples_split', 9), ('n_estimators', 500)])
# Current CV loop R2: [0.2759]
# Running mean R2: 0.2963
# Running shuffle mean R2: -0.0261
# Elapsed time: 672.8
#
#
# 0.29 |
# Best R2: 0.3203 | OrderedDict([('max_features', 0.7244297353369099), ('min_samples_leaf', 6), ('min_samples_split', 2), ('n_estimators', 138)])
# Current CV loop R2: [0.3246]
# Running mean R2: 0.2972
# Running shuffle mean R2: -0.0281
# Elapsed time: 458.6
#
#
# 0.30 |
# Best R2: 0.3644 | OrderedDict([('max_features', 0.6658658988259727), ('min_samples_leaf', 1), ('min_samples_split', 4), ('n_estimators', 500)])
# Current CV loop R2: [0.0083]
# Running mean R2: 0.2879
# Running shuffle mean R2: -0.0302
# Elapsed time: 641.8
#
#
# 0.31 |
# Best R2: 0.3301 | OrderedDict([('max_features', 0.4017596088930312), ('min_samples_leaf', 1), ('min_samples_split', 6), ('n_estimators', 93)])
# Current CV loop R2: [0.3219]
# Running mean R2: 0.289
# Running shuffle mean R2: -0.0339
# Elapsed time: 466.5
#
#
# 0.32 |
# Best R2: 0.3509 | OrderedDict([('max_features', 0.5073228237383961), ('min_samples_leaf', 1), ('min_samples_split', 8), ('n_estimators', 199)])
# Current CV loop R2: [0.1979]
# Running mean R2: 0.2862
# Running shuffle mean R2: -0.0362
# Elapsed time: 483.3
#
#
# 0.33 |
# Best R2: 0.3429 | OrderedDict([('max_features', 0.7570558378000322), ('min_samples_leaf', 1), ('min_samples_split', 2), ('n_estimators', 500)])
# Current CV loop R2: [0.2765]
# Running mean R2: 0.2859
# Running shuffle mean R2: -0.0345
# Elapsed time: 731.2
#
#
# 0.34 |
# Best R2: 0.3181 | OrderedDict([('max_features', 0.5247278761933438), ('min_samples_leaf', 1), ('min_samples_split', 18), ('n_estimators', 353)])
# Current CV loop R2: [0.3902]
# Running mean R2: 0.2889
# Running shuffle mean R2: -0.0345
# Elapsed time: 539.6
#
#
# 0.35 |
# Best R2: 0.3022 | OrderedDict([('max_features', 0.8717876782647568), ('min_samples_leaf', 2), ('min_samples_split', 11), ('n_estimators', 70)])
# Current CV loop R2: [0.3563]
# Running mean R2: 0.2908
# Running shuffle mean R2: -0.0285
# Elapsed time: 438.1
#
#
# 0.36 |
# Best R2: 0.3656 | OrderedDict([('max_features', 0.3510522370949589), ('min_samples_leaf', 1), ('min_samples_split', 9), ('n_estimators', 500)])
# Current CV loop R2: [0.1948]
# Running mean R2: 0.2882
# Running shuffle mean R2: -0.0293
# Elapsed time: 687.9
#
#
# 0.37 |
# Best R2: 0.3331 | OrderedDict([('max_features', 0.37963525007190796), ('min_samples_leaf', 1), ('min_samples_split', 7), ('n_estimators', 454)])
# Current CV loop R2: [0.2777]
# Running mean R2: 0.2879
# Running shuffle mean R2: -0.0313
# Elapsed time: 561.7
#
#
# 0.38 |
# Best R2: 0.3362 | OrderedDict([('max_features', 0.6662340075227895), ('min_samples_leaf', 10), ('min_samples_split', 2), ('n_estimators', 112)])
# Current CV loop R2: [0.2383]
# Running mean R2: 0.2866
# Running shuffle mean R2: -0.0296
# Elapsed time: 425.9
#
#
# 0.39 |
# Best R2: 0.3387 | OrderedDict([('max_features', 0.3796033719694047), ('min_samples_leaf', 4), ('min_samples_split', 6), ('n_estimators', 290)])
# Current CV loop R2: [0.3136]
# Running mean R2: 0.2873
# Running shuffle mean R2: -0.0288
# Elapsed time: 573.9
#
#
# 0.40 |
# Best R2: 0.3201 | OrderedDict([('max_features', 0.7549176372787862), ('min_samples_leaf', 1), ('min_samples_split', 5), ('n_estimators', 500)])
# Current CV loop R2: [0.298]
# Running mean R2: 0.2876
# Running shuffle mean R2: -0.0246
# Elapsed time: 719.9
#
#
# 0.41 |
# Best R2: 0.3449 | OrderedDict([('max_features', 0.3497008190775857), ('min_samples_leaf', 1), ('min_samples_split', 8), ('n_estimators', 198)])
# Current CV loop R2: [0.3704]
# Running mean R2: 0.2895
# Running shuffle mean R2: -0.0231
# Elapsed time: 523.4
#
#
# 0.42 |
# Best R2: 0.3101 | OrderedDict([('max_features', 0.5156403145191194), ('min_samples_leaf', 10), ('min_samples_split', 5), ('n_estimators', 101)])
# Current CV loop R2: [0.3207]
# Running mean R2: 0.2903
# Running shuffle mean R2: -0.0225
# Elapsed time: 443.2
#
#
# 0.43 |
# Best R2: 0.3074 | OrderedDict([('max_features', 0.6978414023679363), ('min_samples_leaf', 2), ('min_samples_split', 32), ('n_estimators', 53)])
# Current CV loop R2: [0.3146]
# Running mean R2: 0.2908
# Running shuffle mean R2: -0.0222
# Elapsed time: 446.3
#
#
# 0.44 |
# Best R2: 0.3058 | OrderedDict([('max_features', 0.32974544033579983), ('min_samples_leaf', 3), ('min_samples_split', 5), ('n_estimators', 500)])
# Current CV loop R2: [0.3528]
# Running mean R2: 0.2922
# Running shuffle mean R2: -0.0211
# Elapsed time: 679.1
#
#
# 0.45 |
# Best R2: 0.3396 | OrderedDict([('max_features', 0.2899198524403984), ('min_samples_leaf', 1), ('min_samples_split', 8), ('n_estimators', 36)])
# Current CV loop R2: [0.3143]
# Running mean R2: 0.2927
# Running shuffle mean R2: -0.0196
# Elapsed time: 458.0
#
#
# 0.46 |
# Best R2: 0.3271 | OrderedDict([('max_features', 0.5972182551107122), ('min_samples_leaf', 3), ('min_samples_split', 2), ('n_estimators', 500)])
# Current CV loop R2: [0.3328]
# Running mean R2: 0.2935
# Running shuffle mean R2: -0.0194
# Elapsed time: 627.0
#
#
# 0.47 |
# Best R2: 0.3249 | OrderedDict([('max_features', 0.48719723132944265), ('min_samples_leaf', 2), ('min_samples_split', 5), ('n_estimators', 500)])
# Current CV loop R2: [0.333]
# Running mean R2: 0.2944
# Running shuffle mean R2: -0.0194
# Elapsed time: 758.4
#
#
# 0.48 |
# Best R2: 0.3235 | OrderedDict([('max_features', 0.5325093170825729), ('min_samples_leaf', 9), ('min_samples_split', 2), ('n_estimators', 98)])
# Current CV loop R2: [0.2584]
# Running mean R2: 0.2936
# Running shuffle mean R2: -0.0166
# Elapsed time: 444.4
#
#
# 0.49 |
# Best R2: 0.3339 | OrderedDict([('max_features', 0.3395235687226681), ('min_samples_leaf', 1), ('min_samples_split', 2), ('n_estimators', 500)])
# Current CV loop R2: [0.2893]
# Running mean R2: 0.2935
# Running shuffle mean R2: -0.0166
# Elapsed time: 695.7
# ```
